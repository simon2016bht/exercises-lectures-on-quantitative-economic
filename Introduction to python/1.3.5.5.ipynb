# %% [markdown]
# #### Your next task is to simulate and plot the correlated time series
# xt+1 = α xt + ϵt+1
# #### where x0 = 0 and t = 0, . . . , T The sequence of shocks {ϵt } is assumed to be iid and standard normal In your solution, restrict your import statements to import numpy as np import matplotlib.pyplot as plt Set T = 200 and α = 0.9

# %%
import numpy as np 
import matplotlib.pyplot as plt

series = np.array([0])
alpha = 0.9
T = 200
for i in range(T):
    disturbance = np.random.normal()
    curr_value = alpha * series[i] + np.random.normal()
    series = np.append(series,curr_value) 

plt.plot(series)
plt.show()
